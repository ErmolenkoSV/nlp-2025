# %% [markdown]
# # Модель "мешок слов"
#
#
# Пусть есть коллекция документов $D$. Будем рассматривать модель *bag-of-words* (мешок слов), то есть каждый документ состоит из какого-то набора слов (терма) без учета их позиций внутри документа.
#
# Рассмотрим коллекцию документов:

# %%
docs = ['человек лев орел черепаха человек', 
        'лев вол орел',
        'лев черепаха лев кошка',
        'жучка кошка мышка',
        'лев орел грифон']

# %% [markdown]
# Посчитаем сколько каждое слово встретилось во всей коллекции и сколько каждом документе:

# %%
import re
import numpy as np
import pandas as pd


from collections import defaultdict, Counter 

def parse_doc(doc):
    return re.split(r'\s+', doc, re.U)

# подсчет df по коллекции
def calc_df_dict(docs):
    c = Counter() 
    for doc_id, doc in enumerate(docs):
        c.update(set(parse_doc(doc)))
    return c 
    
# подсчет tf для документа
def calc_tf_dict(doc):
    c = Counter() 
    for word in parse_doc(doc):
        c[word] += 1
    return c 
    
dfs = calc_df_dict(docs)
pd.DataFrame(data=list(dfs.items()), columns=['term', 'df'])
# Out:
#        term  df
# 0      орел   3
# 1       лев   4
# 2   человек   1
# 3  черепаха   2
# 4       вол   1
# 5     кошка   2
# 6     жучка   1
# 7     мышка   1
# 8    грифон   1

# %% [markdown]
# Каждому слову и каждому документу можно присвоить уникальный численный идентификатор, и построить так называемую tf-матрицу, состоящую из элементов $\{tf_{t,d}\}$ - вес слова $t$ в документе $d$ (где $t = 1 \dots n$ - индексы слов, $j = 1 \dots k$ - индексы документов). Под весом может подразумеваться число вхождений, нормализированная частота, и т.п.
#
# ### Система обозначений SMART
#
# $\{tf_{t,d}\}$ не всегда дает адекватное представление (документы могут быть сильно не равной длины, не учитывается значимость слов). Поэтому существует более сложные модели под обобщенным названием *tf-idf* (term frequency - inverted document frequency), где используется документная частота слова. Идея в том, что для каждого слова в каждом документе считается *tf*, потом *idf* и значения перемножаются. Потом для каждого документа получается вектор, с которым можно что-то сделать (нормализовать).
#
# | Частота термина                                                                                                  | Документная частота                                            | Нормировка                                              |
# |------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------|---------------------------------------------------------|
# | n $$	\text{tf}_{t,d}$$                                                                                             | n $$1$$                                                        | n $$1$$                                                 |
# | l $$1 + \log{\text{tf}_{t,d}}$$                                                                                  | t $$\log{\frac{N}{\text{df}_i}}$$                              | c $$\frac{1}{\sqrt{\omega_1^2 + \ldots + \omega_m^2}}$$ |
# | a $$0.5 + \frac{0.5 \text{tf}_{t,d}}{\max_t{ \text{tf}_{t,d}}}$$                                                 | p $$\text{max}(0, \log{\frac{N - \text{df}_i}{\text{df}_i}})$$ |
# | b $$ 1,  \text{if }  \text{tf}_{t,d} > 0 \text{ else } 0 $$                                                              |
# | L $$\frac{1 + \log{\text{tf}_{t,d}}}{1 + \log{\text{avg}_{t \in d}(\text{tf}_{t,d})}}$$                          |

# %% [markdown]
# ### Ипользование scikit-learn

# %%
docs
# Out:
# ['человек лев орел черепаха человек',
#  'лев вол орел',
#  'лев черепаха лев кошка',
#  'жучка кошка мышка',
#  'лев орел грифон']

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, HashingVectorizer

vectorizer = HashingVectorizer(n_features=5)
vectorizer.fit_transform(docs).toarray()
# Out:
# array([[-0.66666667,  0.66666667,  0.        , -0.33333333,  0.        ],
#        [ 0.        ,  1.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.31622777,  0.9486833 ,  0.        ,  0.        ,  0.        ],
#        [ 0.57735027,  0.        ,  0.        ,  0.57735027,  0.57735027],
#        [ 0.        ,  0.57735027,  0.        , -0.57735027, -0.57735027]])

# %%
print('\n'.join(vectorizer.get_feature_names_out()))
# Out:
# вол
# грифон
# жучка
# кошка
# лев
# мышка
# орел
# человек
# черепаха

# %% [markdown]
# ## Использование в кластеризации, классификации и тематическом моделировании

# %% [markdown]
# Напишем код для чтения и обработки коллекции новостей

# %%
import gzip

from dataclasses import dataclass
from typing import Iterator

from nltk.corpus import stopwords
from yargy.tokenizer import MorphTokenizer


@dataclass
class Text:
    label: str
    title: str
    text: str


def read_texts(fn: str) -> Iterator[Text]:
    with gzip.open(fn, "rt", encoding="utf-8") as f:
        for line in f:
            yield Text(*line.strip().split("\t"))


tokenizer = MorphTokenizer()
ru_stopwords = set(stopwords.words("russian"))


def normalize_text(text: str) -> str:
    tokens = [
        tok.normalized for tok in tokenizer(text) if tok.normalized not in ru_stopwords
    ]
    return " ".join(tokens)

# %%
normalize_text("Привет, миру!")
# Out:
# 'привет , мир !'

# %% [markdown]
# Прочитаем текст и преобразуем документы в вектора

# %%
texts = list(read_texts("data/news.txt.gz"))

# %%
vectorizer = TfidfVectorizer(max_df=0.2, min_df=10)
# vectorizer = HashingVectorizer()

X = vectorizer.fit_transform([normalize_text(text.text) for text in texts]).toarray()

# %% [markdown]
# понизим размерность c помощью `PCA`

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=500)
X = pca.fit_transform(X)

# %%
X.shape
# Out:
# (10000, 500)

# %% [markdown]
# напишем кол для преобразования новых текстов

# %%
def transform_text(text: str) -> np.ndarray:
    normalized_text = normalize_text(text)
    vect = vectorizer.transform([normalized_text]).toarray()
    return pca.transform(vect)

transform_text("привет миру ещё раз")
# Out:
# array([[-3.39188448e-02, -7.66922682e-03, -7.87604734e-03,
#          1.91158993e-03,  1.09120228e-02, -1.92687864e-02,
#          8.63962252e-03,  1.66701950e-02,  6.38762710e-03,
#         -1.73677962e-03,  1.03452127e-02, -3.54432933e-02,
#         -4.87775109e-02, -1.62290554e-02, -2.66548195e-03,
#          2.27416360e-02,  4.50016370e-03, -1.31261483e-03,
#         -3.46951534e-03, -1.18351487e-02,  1.56695989e-02,
#         -6.16911829e-03,  2.25223226e-02, -1.49857922e-02,
#         -5.50197087e-03,  3.98800374e-02,  1.25062014e-02,
#         -4.69092736e-03, -5.58313037e-03,  2.57423417e-03,
#          8.86044439e-03, -1.55273015e-02, -7.09154315e-04,
#         -2.31184327e-03, -7.23467834e-03,  6.70779691e-04,
#         -3.04841716e-02, -2.85352347e-02,  9.88397400e-06,
#          1.81021102e-03,  3.76000184e-03, -1.62727651e-02,
#          9.20342667e-03,  4.11565135e-02, -4.69881257e-03,
#         -3.52405696e-03, -6.88625623e-03,  2.56187939e-03,
#          3.33907959e-02, -2.06297923e-02,  5.13705186e-03,
#          2.12854850e-02, -5.18655614e-04, -4.09713909e-02,
#          1.63394468e-02, -1.30723008e-02, -2.33885142e-02,
#         -1.22651976e-02,  3.95843933e-03,  1.76669741e-03,
#          1.53657522e-02,  1.10943367e-02,  6.50877031e-03,
#          9.84965920e-03, -1.10197240e-02]])

# %% [markdown]
# Кластеризация

# %%
from sklearn.cluster import KMeans

k_means = KMeans(n_clusters=10, n_init="auto")
k_means.fit(X)
# Out:
# KMeans(n_clusters=10)

# %%
[(idx, texts[idx].label)  for idx, cluster in enumerate(k_means.predict(X)) if cluster == 9]
# Out:
# [(19, 'life'),
#  (20, 'media'),
#  (23, 'life'),
#  (36, 'forces'),
#  (39, 'forces'),
#  (46, 'forces'),
#  (47, 'business'),
#  (62, 'sport'),
#  (63, 'life'),
#  (69, 'forces'),
#  (75, 'business'),
#  (86, 'life'),
#  (93, 'forces'),
#  (95, 'culture'),
#  (105, 'life'),
#  (112, 'life'),
#  (124, 'life'),
#  (129, 'life'),
#  (139, 'forces'),
#  (155, 'life'),
#  (175, 'life'),
#  (178, 'culture'),
#  (180, 'media'),
#  (184, 'life'),
#  (186, 'forces'),
#  (193, 'life'),
#  (205, 'media'),
#  (211, 'life'),
#  (215, 'media'),
#  (217, 'media'),
#  (229, 'forces'),
#  (231, 'business'),
#  (239, 'media'),
#  (247, 'forces'),
#  (253, 'forces'),
#  (256, 'life'),
#  (258, 'media'),
#  (264, 'life'),
#  (274, 'life'),
#  (296, 'forces'),
#  (306, 'economics'),
#  (317, 'life'),
#  (340, 'forces'),
#  (343, 'media'),
#  (411, 'forces'),
#  (416, 'travel'),
#  (418, 'science'),
#  (425, 'media'),
#  (430, 'forces'),
#  (435, 'media'),
#  (458, 'life'),
#  (464, 'life'),
#  (471, 'life'),
#  (483, 'media'),
#  (497, 'life'),
#  (499, 'forces'),
#  (502, 'life'),
#  (508, 'media'),
#  (516, 'sport'),
#  (526, 'life'),
#  (545, 'media'),
#  (558, 'life'),
#  (577, 'forces'),
#  (578, 'life'),
#  (600, 'forces'),
#  (635, 'culture'),
#  (642, 'forces'),
#  (651, 'life'),
#  (655, 'media'),
#  (657, 'life'),
#  (659, 'forces'),
#  (660, 'forces'),
#  (668, 'forces'),
#  (688, 'culture'),
#  (692, 'life'),
#  (699, 'life'),
#  (701, 'culture'),
#  (705, 'media'),
#  (708, 'forces'),
#  (726, 'business'),
#  (728, 'media'),
#  (730, 'life'),
#  (745, 'life'),
#  (764, 'forces'),
#  (792, 'life'),
#  (800, 'travel'),
#  (801, 'business'),
#  (808, 'forces'),
#  (820, 'forces'),
#  (833, 'culture'),
#  (844, 'economics'),
#  (859, 'media'),
#  (864, 'forces'),
#  (870, 'forces'),
#  (875, 'media'),
#  (907, 'forces'),
#  (918, 'life'),
#  (919, 'science'),
#  (923, 'life'),
#  (928, 'life'),
#  (941, 'forces'),
#  (944, 'forces'),
#  (960, 'forces'),
#  (981, 'life'),
#  (985, 'life'),
#  (994, 'media'),
#  (1003, 'travel'),
#  (1012, 'life'),
#  (1036, 'forces'),
#  (1066, 'life'),
#  (1072, 'media'),
#  (1081, 'forces'),
#  (1085, 'media'),
#  (1090, 'economics'),
#  (1106, 'business'),
#  (1111, 'forces'),
#  (1116, 'media'),
#  (1119, 'life'),
#  (1184, 'forces'),
#  (1191, 'life'),
#  (1198, 'life'),
#  (1200, 'forces'),
#  (1218, 'forces'),
#  (1226, 'life'),
#  (1230, 'life'),
#  (1233, 'sport'),
#  (1234, 'economics'),
#  (1239, 'travel'),
#  (1240, 'forces'),
#  (1247, 'life'),
#  (1251, 'culture'),
#  (1254, 'forces'),
#  (1255, 'life'),
#  (1267, 'forces'),
#  (1269, 'media'),
#  (1290, 'media'),
#  (1301, 'forces'),
#  (1318, 'forces'),
#  (1324, 'economics'),
#  (1333, 'culture'),
#  (1338, 'forces'),
#  (1385, 'forces'),
#  (1411, 'life'),
#  (1424, 'forces'),
#  (1449, 'forces'),
#  (1460, 'life'),
#  (1464, 'economics'),
#  (1467, 'forces'),
#  (1468, 'economics'),
#  (1471, 'life'),
#  (1474, 'life'),
#  (1482, 'life'),
#  (1490, 'forces'),
#  (1494, 'forces'),
#  (1499, 'forces'),
#  (1513, 'life'),
#  (1516, 'forces'),
#  (1522, 'forces'),
#  (1523, 'life'),
#  (1540, 'forces'),
#  (1541, 'forces'),
#  (1545, 'science'),
#  (1549, 'sport'),
#  (1553, 'life'),
#  (1560, 'economics'),
#  (1566, 'economics'),
#  (1568, 'life'),
#  (1580, 'forces'),
#  (1583, 'forces'),
#  (1588, 'sport'),
#  (1592, 'media'),
#  (1598, 'life'),
#  (1605, 'culture'),
#  (1612, 'media'),
#  (1614, 'media'),
#  (1624, 'life'),
#  (1643, 'forces'),
#  (1677, 'media'),
#  (1683, 'economics'),
#  (1686, 'culture'),
#  (1719, 'forces'),
#  (1720, 'life'),
#  (1722, 'life'),
#  (1727, 'life'),
#  (1733, 'forces'),
#  (1734, 'life'),
#  (1736, 'life'),
#  (1744, 'life'),
#  (1751, 'life'),
#  (1753, 'sport'),
#  (1756, 'media'),
#  (1758, 'life'),
#  (1761, 'forces'),
#  (1763, 'media'),
#  (1772, 'forces'),
#  (1801, 'forces'),
#  (1805, 'forces'),
#  (1808, 'forces'),
#  (1812, 'media'),
#  (1814, 'forces'),
#  (1824, 'life'),
#  (1827, 'economics'),
#  (1834, 'forces'),
#  (1835, 'life'),
#  (1857, 'life'),
#  (1860, 'forces'),
#  (1861, 'media'),
#  (1886, 'life'),
#  (1889, 'forces'),
#  (1907, 'life'),
#  (1916, 'forces'),
#  (1920, 'life'),
#  (1940, 'life'),
#  (1952, 'culture'),
#  (1956, 'media'),
#  (1966, 'life'),
#  (1970, 'media'),
#  (1974, 'media'),
#  (1977, 'media'),
#  (1983, 'forces'),
#  (1989, 'science'),
#  (2010, 'media'),
#  (2019, 'culture'),
#  (2020, 'forces'),
#  (2036, 'media'),
#  (2053, 'culture'),
#  (2059, 'life'),
#  (2081, 'forces'),
#  (2084, 'life'),
#  (2117, 'life'),
#  (2129, 'life'),
#  (2131, 'life'),
#  (2133, 'media'),
#  (2138, 'forces'),
#  (2149, 'life'),
#  (2203, 'life'),
#  (2212, 'forces'),
#  (2213, 'media'),
#  (2217, 'forces'),
#  (2248, 'life'),
#  (2289, 'economics'),
#  (2295, 'forces'),
#  (2304, 'media'),
#  (2305, 'media'),
#  (2307, 'media'),
#  (2347, 'culture'),
#  (4843, 'economics'),
#  (4860, 'life'),
#  (4868, 'media'),
#  (4872, 'economics'),
#  (4875, 'media'),
#  (4892, 'forces'),
#  (4911, 'forces'),
#  (4915, 'life'),
#  (4917, 'media'),
#  (4924, 'sport'),
#  (4926, 'culture'),
#  (4941, 'life'),
#  (4949, 'life'),
#  (4953, 'media'),
#  (4957, 'forces'),
#  (4976, 'forces'),
#  (4986, 'media'),
#  (4988, 'media'),
#  (4997, 'sport'),
#  (5016, 'economics'),
#  (5025, 'culture'),
#  (5031, 'business'),
#  (5063, 'forces'),
#  (5074, 'business'),
#  (5081, 'life'),
#  (5084, 'life'),
#  (5090, 'forces'),
#  (5097, 'forces'),
#  (5099, 'life'),
#  (5102, 'forces'),
#  (5105, 'life'),
#  (5107, 'forces'),
#  (5117, 'economics'),
#  (5118, 'forces'),
#  (5123, 'media'),
#  (5129, 'forces'),
#  (5131, 'forces'),
#  (5144, 'economics'),
#  (5160, 'forces'),
#  (5161, 'media'),
#  (5167, 'life'),
#  (5186, 'life'),
#  (5187, 'life'),
#  (5192, 'forces'),
#  (5195, 'life'),
#  (5197, 'media'),
#  (5200, 'forces'),
#  (5210, 'forces'),
#  (5211, 'life'),
#  (5223, 'life'),
#  (5226, 'forces'),
#  (5262, 'forces'),
#  (5273, 'life'),
#  (5281, 'media'),
#  (5294, 'forces'),
#  (5312, 'forces'),
#  (5342, 'media'),
#  (5348, 'life'),
#  (5352, 'life'),
#  (5354, 'life'),
#  (5360, 'life'),
#  (5375, 'forces'),
#  (5386, 'life'),
#  (5397, 'media'),
#  (5401, 'economics'),
#  (5402, 'media'),
#  (5403, 'media'),
#  (5447, 'culture'),
#  (5456, 'forces'),
#  (5457, 'life'),
#  (5458, 'life'),
#  (5469, 'life'),
#  (5476, 'forces'),
#  (5486, 'media'),
#  (5509, 'forces'),
#  (5525, 'life'),
#  (5540, 'life'),
#  (5569, 'media'),
#  (5588, 'forces'),
#  (5589, 'media'),
#  (5594, 'media'),
#  (5604, 'business'),
#  (5613, 'forces'),
#  (5620, 'sport'),
#  (5625, 'sport'),
#  (5635, 'life'),
#  (5654, 'media'),
#  (5655, 'media'),
#  (5657, 'forces'),
#  (5666, 'culture'),
#  (5667, 'life'),
#  (5674, 'economics'),
#  (5676, 'life'),
#  (5689, 'culture'),
#  (5693, 'life'),
#  (5707, 'life'),
#  (5710, 'forces'),
#  (5731, 'forces'),
#  (5754, 'life'),
#  (5768, 'life'),
#  (5769, 'forces'),
#  (5778, 'forces'),
#  (5788, 'life'),
#  (5796, 'media'),
#  (5805, 'life'),
#  (5815, 'media'),
#  (5816, 'life'),
#  (5829, 'business'),
#  (5868, 'economics'),
#  (5872, 'travel'),
#  (5878, 'life'),
#  (5910, 'life'),
#  (5918, 'life'),
#  (5923, 'forces'),
#  (5930, 'media'),
#  (5944, 'economics'),
#  (5965, 'life'),
#  (5967, 'forces'),
#  (5976, 'media'),
#  (5984, 'life'),
#  (5995, 'forces'),
#  (6025, 'media'),
#  (6052, 'life'),
#  (6057, 'forces'),
#  (6066, 'life'),
#  (6067, 'media'),
#  (6071, 'sport'),
#  (6101, 'media'),
#  (6105, 'media'),
#  (6113, 'forces'),
#  (6118, 'sport'),
#  (6121, 'media'),
#  (6158, 'life'),
#  (6173, 'life'),
#  (6185, 'forces'),
#  (6191, 'economics'),
#  (6199, 'forces'),
#  (6202, 'travel'),
#  (6203, 'forces'),
#  (6209, 'forces'),
#  (6212, 'forces'),
#  (6214, 'forces'),
#  (6224, 'forces'),
#  (6226, 'life'),
#  (6231, 'culture'),
#  (6235, 'media'),
#  (6236, 'science'),
#  (6260, 'media'),
#  (6265, 'life'),
#  (6266, 'forces'),
#  (6267, 'life'),
#  (6269, 'forces'),
#  (6276, 'economics'),
#  (6292, 'media'),
#  (6299, 'culture'),
#  (6310, 'life'),
#  (6321, 'forces'),
#  (6363, 'forces'),
#  (6378, 'forces'),
#  (6384, 'forces'),
#  (6399, 'media'),
#  (6402, 'life'),
#  (6403, 'life'),
#  (6412, 'life'),
#  (6418, 'forces'),
#  (6429, 'forces'),
#  (6446, 'culture'),
#  (6460, 'life'),
#  (6472, 'life'),
#  (6520, 'culture'),
#  (6528, 'forces'),
#  (6539, 'culture'),
#  (6540, 'life'),
#  (6541, 'life'),
#  (6549, 'business'),
#  (6559, 'forces'),
#  (6561, 'culture'),
#  (6571, 'life'),
#  (6584, 'life'),
#  (6594, 'forces'),
#  (6601, 'economics'),
#  (6606, 'life'),
#  (6614, 'sport'),
#  (6616, 'forces'),
#  (6632, 'life'),
#  (6637, 'forces'),
#  (6649, 'life'),
#  (6660, 'life'),
#  (6666, 'life'),
#  (6677, 'forces'),
#  (6697, 'sport'),
#  (6699, 'forces'),
#  (6717, 'life'),
#  (6719, 'life'),
#  (6761, 'life'),
#  (6785, 'life'),
#  (6787, 'forces'),
#  (6817, 'forces'),
#  (6820, 'forces'),
#  (6841, 'life'),
#  (6852, 'forces'),
#  (6892, 'life'),
#  (6902, 'economics'),
#  (6906, 'life'),
#  (6918, 'forces'),
#  (6928, 'forces'),
#  (6931, 'sport'),
#  (6939, 'media'),
#  (6945, 'forces'),
#  (6946, 'science'),
#  (6948, 'culture'),
#  (6951, 'life'),
#  (6960, 'travel'),
#  (6973, 'life'),
#  (6974, 'media'),
#  (6978, 'life'),
#  (6991, 'forces'),
#  (6992, 'forces'),
#  (6995, 'forces'),
#  (6999, 'economics'),
#  (7001, 'media'),
#  (7016, 'media'),
#  (7022, 'forces'),
#  (7034, 'life'),
#  (7047, 'forces'),
#  (7053, 'economics'),
#  (7059, 'forces'),
#  (7065, 'business'),
#  (7066, 'business'),
#  (7071, 'travel'),
#  (7080, 'forces'),
#  (7086, 'forces'),
#  (7094, 'life'),
#  (7104, 'forces'),
#  (7108, 'forces'),
#  (7111, 'life'),
#  (7126, 'life'),
#  (7135, 'media'),
#  (7139, 'forces'),
#  (7149, 'forces'),
#  (7154, 'media'),
#  (7163, 'life'),
#  (7165, 'forces'),
#  (7170, 'forces'),
#  (7175, 'life'),
#  (7200, 'life'),
#  (7207, 'media'),
#  (7263, 'forces'),
#  (7266, 'sport'),
#  (7278, 'economics'),
#  (7293, 'forces'),
#  (7297, 'forces'),
#  (8568, 'life'),
#  (8587, 'life'),
#  (8597, 'forces'),
#  (8598, 'life'),
#  (8612, 'life'),
#  (8627, 'media'),
#  (8630, 'forces'),
#  (8648, 'forces'),
#  (8650, 'life'),
#  (8658, 'life'),
#  (8684, 'forces'),
#  (8692, 'forces'),
#  (8704, 'life'),
#  (8706, 'sport'),
#  (8711, 'media'),
#  (8716, 'economics'),
#  (8722, 'forces'),
#  (8725, 'life'),
#  (8738, 'life'),
#  (8745, 'media'),
#  (8748, 'media'),
#  (8792, 'media'),
#  (8799, 'life'),
#  (8811, 'life'),
#  (8817, 'life'),
#  (8821, 'life'),
#  (8838, 'culture'),
#  (8855, 'forces'),
#  (8860, 'forces'),
#  (8861, 'forces'),
#  (8863, 'economics'),
#  (8867, 'forces'),
#  (8872, 'forces'),
#  (8873, 'forces'),
#  (8894, 'forces'),
#  (8904, 'business'),
#  (8908, 'forces'),
#  (8909, 'forces'),
#  (8913, 'life'),
#  (8919, 'culture'),
#  (8934, 'media'),
#  (8943, 'media'),
#  (8961, 'forces'),
#  (8966, 'media'),
#  (8967, 'media'),
#  (8970, 'forces'),
#  (8980, 'media'),
#  (8981, 'life'),
#  (8985, 'life'),
#  (8987, 'life'),
#  (9006, 'forces'),
#  (9021, 'culture'),
#  (9060, 'forces'),
#  (9081, 'life'),
#  (9097, 'business'),
#  (9106, 'life'),
#  (9108, 'media'),
#  (9110, 'life'),
#  (9119, 'media'),
#  (9134, 'life'),
#  (9138, 'life'),
#  (9147, 'life'),
#  (9156, 'life'),
#  (9160, 'travel'),
#  (9168, 'forces'),
#  (9182, 'forces'),
#  (9183, 'life'),
#  (9185, 'life'),
#  (9187, 'forces'),
#  (9192, 'life'),
#  (9199, 'forces'),
#  (9203, 'life'),
#  (9228, 'forces'),
#  (9235, 'forces'),
#  (9245, 'forces'),
#  (9247, 'life'),
#  (9265, 'life'),
#  (9273, 'life'),
#  (9277, 'life'),
#  (9281, 'media'),
#  (9291, 'life'),
#  (9314, 'forces'),
#  (9319, 'media'),
#  (9334, 'life'),
#  (9347, 'sport'),
#  (9357, 'life'),
#  (9358, 'life'),
#  (9368, 'forces'),
#  (9380, 'media'),
#  (9422, 'forces'),
#  (9439, 'forces'),
#  (9448, 'forces'),
#  (9454, 'media'),
#  (9463, 'life'),
#  (9464, 'life'),
#  (9480, 'forces'),
#  (9485, 'life'),
#  (9490, 'sport'),
#  (9501, 'life'),
#  (9513, 'business'),
#  (9520, 'forces'),
#  (9524, 'forces'),
#  (9538, 'media'),
#  (9539, 'life'),
#  (9544, 'forces'),
#  (9545, 'forces'),
#  (9559, 'life'),
#  (9573, 'life'),
#  (9580, 'life'),
#  (9594, 'forces'),
#  (9597, 'life'),
#  (9600, 'media'),
#  (9606, 'life'),
#  (9612, 'forces'),
#  (9626, 'media'),
#  (9627, 'forces'),
#  (9629, 'life'),
#  (9636, 'sport'),
#  (9640, 'life'),
#  (9641, 'media'),
#  (9657, 'life'),
#  (9664, 'media'),
#  (9674, 'life'),
#  ...]

# %%
texts[62]
# Out:
# Text(label='sport', title='Супруга Немова рассказала о планах гимнаста разобраться со «СтопХамом»', text='Российский гимнаст, четырехкратный олимпийский чемпион Алексей Немов намерен разобраться в конфликте с активистами движения «СтопХам», с которыми у него произошла стычка. Об этом сообщает «Русская служба новостей» со ссылкой на супругу спортсмена Галину Немову.Материалы по теме13:14 16 февраля 2016«Подрался с детьми. Орал как баба»Реакция соцсетей на конфликт Алексея Немова с активистами «СтопХама»«Мы думаем, как поступить в этой ситуации, потому что такое может произойти с каждым, хочется как-то наказать этих людей. Это провокация настоящая. Они ведут себя так интеллигентно, при этом провоцируют, стучат в окно и спрашивают: "Что же вы делаете?". А что — ты даже не понимаешь в этой ситуации. Что это, Алексей тоже для себя хочет разобрать», — сказала Немова.Супруга гимнаста выразила мнение, что случившееся было провокацией. Она отметила, что ее муж просил активистов отойти от автомобиля. «Алексей порядочный человек, он попросил их отойти от машины. Я в этот момент отошла, так как Алексей остановился, чтобы я вышла в уборную. Минут 5-7 на все ушло. Я прихожу, Алексей споткнулся, они ему руку завернули, он разбил часы, сломалось зеркало у машины», — добавила она.Как утверждает Галина Немова, ее супруг не нарушил правил парковки, поскольку в этом месте «все стоят» и «никакого беспорядка вообще нет». Она также добавила, что в момент конфликта в автомобиле сидел ребенок, у которого из-за происходящего началась истерика.Ранее 15 февраля движение «СтопХам» опубликовало видеозапись конфликта с Немовым. Как заявил руководитель движения Дмитрий Чугунов, активисты сделали замечание бывшему спортсмену, так как он припарковался на проезжей части. Они попросили Немова найти другое место для парковки, но тот отказался. Представители «СтопХама» прикрепили на автомобиль олимпийского чемпиона наклейку с надписью «Мне плевать на всех — я паркуюсь, где хочу», после чего Немов набросился на них с кулаками.Общественное движение «СтопХам» ставит своей целью борьбу с проявлениями грубых нарушений правил дорожного движения, грубостью водителей и пренебрежением нормами цивилизованного поведения на дорогах.')

# %% [markdown]
# Классификация

# %%
from sklearn.svm import SVC

y = [text.label for text in texts]

svc = SVC()
svc.fit(X, y)
# Out:
# SVC()

# %%
svc.predict(transform_text("путешествие в японию"))
# Out:
# array(['science'], dtype='<U9')

# %% [markdown]
# Тематическое моделирование

# %%
import re

from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel 

normalized_tokens = [
    re.findall(r"\b\w+\b", normalize_text(text.text))
    for text in texts
]
dictionary = Dictionary(normalized_tokens)

corpus = [dictionary.doc2bow(text) for text in normalized_tokens]

lda = LdaModel(corpus, num_topics=10)

# %%
id2token = {v : k for (k, v) in dictionary.token2id.items()}
[(id2token[token_id], p) for (token_id, p) in lda.get_topic_terms(9, 20)]
# Out:
# [('который', 0.00830321),
#  ('год', 0.0054368204),
#  ('это', 0.004838807),
#  ('компания', 0.0043977294),
#  ('сообщать', 0.0036527005),
#  ('также', 0.0031273172),
#  ('полиция', 0.0029178592),
#  ('доллар', 0.002819416),
#  ('время', 0.00247647),
#  ('мочь', 0.0024313491),
#  ('миллион', 0.0022946375),
#  ('свой', 0.0022523808),
#  ('реклама', 0.0022084913),
#  ('самолёт', 0.0022002487),
#  ('мечело', 0.002067581),
#  ('сотрудник', 0.0020038143),
#  ('однако', 0.0019964536),
#  ('стать', 0.001971077),
#  ('около', 0.001962201),
#  ('кипр', 0.0018835498)]
